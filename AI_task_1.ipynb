# %%
print('Welcome')
# Out:
# Welcome

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/91950/OneDrive/Desktop/Health.csv')
df['age'] = df['age']
plt.figure(figsize = (16,8))
sns.histplot(data = df,x = 'age')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/91950/OneDrive/Desktop/Health.csv')
df1 = df[df['gender'] == 'Female']
df2 = df[df['gender'] == 'Male']
df1 = df1.sort_values(by = 'age')
plt.figure(figsize = (16,8))
sns.histplot(data = df1,x = 'age',label = 'Female')

plt.show()
df2 = df2.sort_values(by = 'age')
plt.figure(figsize = (16,8))
sns.histplot(data = df2,x = 'age',label = 'Male',color = 'Orange')
plt.show()

#Clearly our graph plots show that the most of the people facing diabetes problem is in the age group 70-80

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/91950/OneDrive/Desktop/Health.csv')
df = df.sort_values(by = 'age')

# v = df.groupby(['age'])['num_lab_procedures']
plt.figure(figsize = (16,8))
sns.barplot(data = df,x = 'age',y = 'num_lab_procedures')

plt.xlabel('Age Group')
plt.ylabel('Number of Lab Procedures')
plt.title('Number of Lab Procedures for different age groups')
plt.show()


# The dark line in each of the bar plot tells us the error in data. In this case it is most probably the standard deviation of the data in each age group

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('C:/Users/91950/OneDrive/Desktop/Health.csv')
hue_order=['Female','Male']
plt.figure(figsize = (16,8))
sns.countplot(data = df,x = 'age',hue = 'gender')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.subplot(2,1,1)
sns.countplot(data = df,x = 'readmitted')
plt.xlabel('Readmission of patient(in days)')

plt.ylabel('Number of Patients readmitted')
plt.title('Data of Readmission of Patients')


hue_order = ['>30','<30','No']
plt.figure(figsize = (16,8))
plt.subplot(2,1,2)
sns.countplot(data = df,x = 'time_in_hospital',hue = 'readmitted')
plt.xlabel('Time spent in Hospital')
plt.ylabel('Number of Patients')
plt.title('Variation of Time spent by patients and Readmission statuts')
plt.show()

# %%
sns.countplot(data = df,x = 'metformin',order = df['metformin'].value_counts().index)
print(df['metformin'].value_counts().tail(3).sum())
plt.show()
#sns.countplot(ax = axes[2, 0], x = 'Brand', data = data, color = 'blue', order = data['Brand'].head(20).value_counts().index);
# Out:
# 19988

# %%
df.describe(include = 'all').T
# Out:
#                              count unique        top    freq  \
# encounter_id              101766.0    NaN        NaN     NaN
# patient_nbr               101766.0    NaN        NaN     NaN
# race                        101766      6  Caucasian   76099
# gender                      101766      3     Female   54708
# age                         101766     10    [70-80)   26068
# weight                      101766     10          ?   98569
# admission_type_id         101766.0    NaN        NaN     NaN
# discharge_disposition_id  101766.0    NaN        NaN     NaN
# admission_source_id       101766.0    NaN        NaN     NaN
# time_in_hospital          101766.0    NaN        NaN     NaN
# payer_code                  101766     18          ?   40256
# medical_specialty           101766     73          ?   49949
# num_lab_procedures        101766.0    NaN        NaN     NaN
# num_procedures            101766.0    NaN        NaN     NaN
# ...

# %% [markdown]
# Top 10 Prescribed Medicine

# %%
data = {'Medication':[],'Count':[]}
new_df = pd.DataFrame(data)
new_row = pd.DataFrame({'Medication':['Metformin'],
                       'Count':[df['metformin'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['Repaglinide'],
                       'Count':[df['repaglinide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['Nateglinide'],
                       'Count':[df['nateglinide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['chlorpropamide'],
                       'Count':[df['chlorpropamide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['glimepiride'],
                       'Count':[df['glimepiride'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['acetohexamide'],
                       'Count':[df['acetohexamide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['glipizide'],
                       'Count':[df['glipizide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['glyburide'],
                       'Count':[df['glyburide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['tolbutamide'],
                       'Count':[df['tolbutamide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['pioglitazone'],
                       'Count':[df['pioglitazone'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['rosiglitazone'],
                       'Count':[df['rosiglitazone'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['acarbose'],
                       'Count':[df['acarbose'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['miglitol'],
                       'Count':[df['miglitol'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['troglitazone'],
                       'Count':[df['troglitazone'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)
new_row = pd.DataFrame({'Medication':['tolazamide'],
                       'Count':[df['tolazamide'].value_counts().tail(3).sum()]})
new_df = pd.concat([new_df, new_row], ignore_index=True)

newest_df = new_df.sort_values(by = 'Count',ascending = False).head(10)
sns.barplot(data = newest_df,x = 'Medication',y = 'Count')
plt.xticks(rotation = 90)
plt.show()
print(newest_df['Medication'])
# new_df
# Out:
# 5     acetohexamide
# 14       tolazamide
# 8       tolbutamide
# 13     troglitazone
# 0         Metformin
# 6         glipizide
# 7         glyburide
# 9      pioglitazone
# 10    rosiglitazone
# 4       glimepiride
# Name: Medication, dtype: object

# %% [markdown]
# What is the relation Number of days patient stayed v/s age group

# %%
sns.barplot(data = df,x = 'age',y = 'time_in_hospital')
plt.title('Time in Hospital v/s Age group')
plt.show()

# %% [markdown]
# Time in Hospital v/s Age in different genders

# %%
plt.figure(figsize = (16,8))
sns.barplot(data = df,x = 'age',y = 'time_in_hospital',hue = 'gender')
plt.title('Time in Hospital v/s Age group')
plt.show()

# %% [markdown]
# Male v/s Female count

# %%
sns.countplot(x = 'gender',data = df)
plt.show()

# %%
count = df['gender'].value_counts()
count.plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#000000'], labels=count.index)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# What are the different races that reach the hospital?

# %%
sns.countplot(data = df,x = 'race')
plt.xticks(rotation = 80)
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = df,x = 'age',y = 'time_in_hospital',hue = 'gender')
plt.title('Time in Hospital v/s Age group')
plt.show()

# %% [markdown]
# Number of People with Diabetic Medicine?

# %%
sns.countplot(data = df,x = 'diabetesMed')
plt.ylabel('People taking Medicine for Diabetes')
plt.xlabel('Medicine')
plt.show()

# %%
count = df['diabetesMed'].value_counts()
count.plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#000000'], labels=count.index)
plt.title('Diabetic Medicines')
plt.show()

# %% [markdown]
# Count of People with different levels of insulin

# %%
sns.countplot(data = df,x = 'insulin')
plt.show()

# %%
count = df['insulin'].value_counts()
count.plot.pie(autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#66b999','#ff93ff'], labels=count.index)
plt.title('Insulin Distibution')
plt.show()
